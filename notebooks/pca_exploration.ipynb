# %%
import sys
sys.path.insert(1, '../utils/')
import se_analysis as sea

import pandas as pd

# %% [markdown]
# #### Health Data

# %%
df = pd.read_csv("../data/processed/health.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[6:],n_components=10,max_iter=5,fig_width=8,fig_height=3)
# Out:
# [IterativeImputer] Completing matrix with shape (25444, 42)
# [IterativeImputer] Change: 397.75814192325436, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 244.93154221457468, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 14.321122863751658, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 6.911368444994725, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 2.674994024713376, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 1.6640457401947284, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 1.9498886829679134, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 2.138492312007242, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 2.262870716227085, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Change: 2.361491770895918, scaled tolerance: 0.023602262549675897
# [IterativeImputer] Completing matrix with shape (25444, 42)

# %% [markdown]
# #### FBI Crime Data

# %%
df = pd.read_csv("../data/processed/fbi_crime.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[6:],n_components=10,max_iter=10,fig_width=8,fig_height=3)
# Out:
# [IterativeImputer] Completing matrix with shape (20856, 16)
# [IterativeImputer] Change: 56.51164688115144, scaled tolerance: 0.053233850424670666
# [IterativeImputer] Change: 5.296184072500765e-05, scaled tolerance: 0.053233850424670666
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (20856, 16)

# %% [markdown]
# #### UCR Crime Data

# %%
df = pd.read_csv("../data/processed/ucr_crime.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[6:],n_components=10,max_iter=5,fig_width=8,fig_height=3)
# Out:
# [IterativeImputer] Completing matrix with shape (9532, 115)
# [IterativeImputer] Change: 2.8252531928171853, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 2.2366730648861655, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 1.2984925623062076, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 1.1958423679015306, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 1.1103896015041401, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 1.0379578620798897, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 0.9746793857124103, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 0.9181488290350955, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 0.8676326405290395, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Change: 0.8212374298628528, scaled tolerance: 0.07582567781368409
# [IterativeImputer] Completing matrix with shape (9532, 115)

# %% [markdown]
# #### School Data

# %%
df = pd.read_csv("../data/processed/School_Digger_2018_D.csv")
df.loc[df["% Students Receiving Free or DisNumbered Lunch"].str.contains("#DIV/0!"), ["% Students Receiving Free or DisNumbered Lunch"]] = 0
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[4:],n_components=10,max_iter=10,fig_width=8,fig_height=3)
# Out:
# [IterativeImputer] Completing matrix with shape (18787, 23)
# [IterativeImputer] Change: 11.544602750515113, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 8.648081136626583, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 5.2078124514336785, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 3.7495668615000315, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 2.299338041376915, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 1.7922523847726959, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 1.845112579895766, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 1.6343163259625553, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 1.3353733192413926, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Change: 1.039109229413727, scaled tolerance: 0.1370620297529553
# [IterativeImputer] Completing matrix with shape (18787, 23)

# %% [markdown]
# #### Population Data

# %%
df = pd.read_csv("../data/processed/population_estimate.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[4:],n_components=10,max_iter=1,fig_width=8,fig_height=3)
# Out:
# [IterativeImputer] Completing matrix with shape (25760, 743)
# [IterativeImputer] Change: 6.5394327640292165, scaled tolerance: 0.08589853139732499
# [IterativeImputer] Completing matrix with shape (25760, 743)
