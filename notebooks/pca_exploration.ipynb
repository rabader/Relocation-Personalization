# %%
import sys
sys.path.insert(1, '../utils/')
import se_analysis as sea

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# #### Health Data

# %%
df = pd.read_csv("../data/processed/health.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[6:],n_components=5,fig_width=8,fig_height=2)
# Out:
# c:\ProgramData\Miniconda3\envs\siads699\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SimpleImputer was fitted without feature names
#   warnings.warn(

# %% [markdown]
# #### FBI Crime Data

# %%
df = pd.read_csv("../data/processed/fbi_crime.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[6:],n_components=5,fig_width=8,fig_height=2)
# Out:
# c:\ProgramData\Miniconda3\envs\siads699\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SimpleImputer was fitted without feature names
#   warnings.warn(

# %% [markdown]
# #### UCR Crime Data

# %%
df = pd.read_csv("../data/processed/ucr_crime.csv.gz")
pca_features,pca_chart = sea.get_pca_components(df,feature_col_lst=df.columns[6:],n_components=5,fig_width=8,fig_height=2)
# Out:
# c:\ProgramData\Miniconda3\envs\siads699\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SimpleImputer was fitted without feature names
#   warnings.warn(
